# %% [markdown]
# # Tandem Repeat analysis
# #### Written by Jigar N. Bandaria
# In this file we continue the analysis on the files that were saved in the previous notebook 'sgRNA analysis 1'

# %%
# %matplotlib inline
import pandas as pd
import numpy as np

# %%
#Loading and checking the contents of the file
dups = pd.read_csv('/home/user/Desktop/nt_17/dup_uni/all_dup_ex_nochrp.fa',header=None,sep='\t',names=['Sequence','Chromosome','Position'])
dups.head()
# Out:
#             Sequence Chromosome        Position
# 0  GCCTCACTCTGTCACCC      chr10  61207-61224(+)
# 1  CACTCTGTCACCCAGGT      chr10  61211-61228(+)
# 2  TTGAGCCCAGGAGCTTG      chr10  61265-61282(-)
# 3  TACTTAGGAGGCTGAGG      chr10  61294-61311(-)
# 4  AGCTACTTAGGAGGCTG      chr10  61297-61314(-)

# %%
len(dups) #Total number of sequences
# Out:
# 37931217

# %%
#Grouping and checking the chromosome distribution of each sequence
data2 = dups.groupby(['Sequence'])['Chromosome'].unique()
data2

#There are some sequences that are present on multiple chromosomes.
# Out:
# Sequence
# AAAAAAAAAACCGCACG                                               [chr2]
# AAAAAAAAAACCGGTCC                                               [chrY]
# AAAAAAAAAAGACCCGG                                               [chrX]
# AAAAAAAAAAGGAGCCG                                               [chr9]
# AAAAAAAAAAGGCGAGG                                              [chr19]
# AAAAAAAAAAGGGAGCG                                               [chr1]
# AAAAAAAAAAGGGCAGC                                               [chr4]
# AAAAAAAAACAGCGGCC                                               [chr2]
# AAAAAAAAACAGCTGGC                                              [chr17]
# AAAAAAAAACATGGCCC                                              [chr22]
# AAAAAAAAACCGCACTG                                               [chr1]
# AAAAAAAAACCGCGCAA                                               [chr4]
# AAAAAAAAACCGGTCCT                                               [chrY]
# AAAAAAAAACTCGCCTG                                               [chr1]
# AAAAAAAAACTGGCCTG                                               [chr6]
# AAAAAAAAAGACCGCCA                                              [chr18]
# AAAAAAAAAGAGACCGG                                               [chr4]
# AAAAAAAAAGAGGCTCC                                              [chr15]
# AAAAAAAAAGCAGAGCC                                               [chr9]
# AAAAAAAAAGCAGCCCC                                              [chr16]
# AAAAAAAAAGCCAGGCA    [chr10, chr11, chr12, chr13, chr14, chr15, chr...
# AAAAAAAAAGCCGGGCA    [chr10, chr11, chr12, chr13, chr14, chr15, chr...
# AAAAAAAAAGCCGGGTG    [chr10, chr11, chr12, chr13, chr14, chr15, chr...
# AAAAAAAAAGCGGCAGC                                               [chr7]
# AAAAAAAAAGCTGGGCA    [chr10, chr11, chr12, chr13, chr14, chr15, chr...
# AAAAAAAAAGGACAGGG                                              [chr12]
# AAAAAAAAAGGAGAGCC                                              [chr10]
# AAAAAAAAAGGCAGCTG                                               [chr2]
# AAAAAAAAAGGCTGGGG                                   [chr3, chr5, chr7]
# AAAAAAAAAGGGAGCGG                                               [chr1]
#                                            ...
# TTTTTTTTGGTTGGTCC                                               [chr2]
# TTTTTTTTGTCAGAGGC                                               [chr7]
# TTTTTTTTGTCATGGGG                                               [chr9]
# TTTTTTTTGTCTGCCAC                                               [chr9]
# TTTTTTTTGTGGGTTGG                                              [chr14]
# TTTTTTTTGTGTGGGGA                                               [chr2]
# TTTTTTTTGTTGGGGCT                                               [chr2]
# TTTTTTTTTCACCACCG                                               [chr1]
# TTTTTTTTTCCAGACGG                                               [chrY]
# TTTTTTTTTCGGGGATG                                              [chr16]
# TTTTTTTTTCGGGGCAG                                               [chr1]
# TTTTTTTTTGACCAGGC                                              [chr10]
# TTTTTTTTTGAGGGCGG                                              [chr17]
# TTTTTTTTTGCACAGGC                                               [chr7]
# TTTTTTTTTGCATGGGG                                               [chrY]
# TTTTTTTTTGCCAGGGA                                               [chr1]
# TTTTTTTTTGCGGTTGC                                               [chrY]
# TTTTTTTTTGCTGGGGA                                               [chr1]
# TTTTTTTTTGTAGCGGG                                              [chr17]
# TTTTTTTTTTCAGGGGG                                               [chr8]
# TTTTTTTTTTCGGGGCA                                               [chr1]
# TTTTTTTTTTGAGGGCG                                              [chr17]
# TTTTTTTTTTGCCCCGA                                              [chr17]
# TTTTTTTTTTGCGGCGG                                        [chr17, chr1]
# TTTTTTTTTTGCGGGAG                                               [chr1]
# TTTTTTTTTTGCTCCCC                                               [chr7]
# TTTTTTTTTTGGCAGCG                                               [chr7]
# TTTTTTTTTTGGGGGGG    [chr10, chr11, chr12, chr13, chr14, chr15, chr...
# TTTTTTTTTTGGTGGGG    [chr10, chr11, chr12, chr13, chr14, chr15, chr...
# TTTTTTTTTTGTCGGGG                                               [chrX]
# Name: Chromosome, dtype: object

# %%
print ("Dups : {}".format(len(dups)))
print ("Data2 : {}".format(len(data2)))
# Out:
# Dups : 37931217
# Data2 : 2450798

# %% [markdown]
# Below we remove those duplicates that are spread over multiple chromosomes.

# %%
more_than_one = [len(x)!=1 for x in data2.values]
mult_chrom = data2.index[more_than_one].tolist()
print ("Length of more_than_one : {}".format(len(more_than_one)))
print ("Length of mult_chrom : {}".format(len(mult_chrom)))
mult_chrom[:10]
# Out:
# Length of more_than_one : 2450798
# Length of mult_chrom : 57610
# ['AAAAAAAAAGCCAGGCA',
#  'AAAAAAAAAGCCGGGCA',
#  'AAAAAAAAAGCCGGGTG',
#  'AAAAAAAAAGCTGGGCA',
#  'AAAAAAAAAGGCTGGGG',
#  'AAAAAAAAATCCCTGCG',
#  'AAAAAAAAGAGGAGGGC',
#  'AAAAAAAAGGCCAGGCA',
#  'AAAAAAAAGGCCGGGCA',
#  'AAAAAAAAGGCTGGGCA']

# %%
dups_reduced = dups.mask(dups.Sequence.isin(mult_chrom))

# %%
dups_reduced.dropna(how='any',inplace=True)
dups_reduced
# Out:
#                    Sequence Chromosome              Position
# 1213      TTCAGCTTCCAGCTCCC      chr10      123165-123182(+)
# 1216      TTCAGCTTCCAGCTCCC      chr10      123185-123202(+)
# 1252      CTCAGGGTGGAGGCTCA      chr10      125637-125654(-)
# 1253      GCTCAGGGTGGAGGCTC      chr10      125638-125655(-)
# 1254      CTGGGCTGAGCTCAGGG      chr10      125647-125664(-)
# 1255      GCTCTGGGCTGAGCTCA      chr10      125650-125667(-)
# 1256      AGCTCTGGGCTGAGCTC      chr10      125651-125668(-)
# 1257      CTCAGGGTGGAGGCTCA      chr10      125673-125690(-)
# 1258      GCTCAGGGTGGAGGCTC      chr10      125674-125691(-)
# 1259      CTGGGCTGAGCTCAGGG      chr10      125683-125700(-)
# 1260      GCTCTGGGCTGAGCTCA      chr10      125686-125703(-)
# 1261      AGCTCTGGGCTGAGCTC      chr10      125687-125704(-)
# 1265      TGAGCCTCCATCCAGAG      chr10      126193-126210(+)
# 1266      CTTTTCTGTGACCATCA      chr10      126456-126473(-)
# 1267      CCTCTTGCTCCTCCTCC      chr10      126736-126753(+)
# 1270      TACCACCTTGGGGAAAA      chr10      127779-127796(+)
# 1271      CCCAACAGGGCAACAGA      chr10      128212-128229(+)
# 1272      CCCTTCCCCACAGCCAC      chr10      128353-128370(+)
# 1273      GTCATCAGCTCCAAGGC      chr10      130613-130630(+)
# 1274      CCCAGCAGATTGCTCAG      chr10      132252-132269(+)
# 1310      TGGACAGGCTCTCTAGA      chr10      134767-134784(+)
# 1311      ACAGGCTCTCTAGAAGG      chr10      134770-134787(+)
# 1312      CTCTCTAGAAGGTAGAC      chr10      134795-134812(+)
# 1313      TAGACAGGCTCTCTAGA      chr10      134807-134824(+)
# 1314      CTCTCTAGAAGGTAGAC      chr10      134815-134832(+)
# 1315      TAGACAGGCTCTCTAGA      chr10      134827-134844(+)
# 1316      ACAGGCTCTCTAGAGGG      chr10      134830-134847(+)
# 1317      CTCTCTAGAGGGTGGAC      chr10      134835-134852(+)
# 1318      TGGACAGGCTCTCTAGA      chr10      134847-134864(+)
# 1319      ACAGGCTCTCTAGAAGG      chr10      134850-134867(+)
# ...                     ...        ...                   ...
# 37926586  CTAGGCTCTGCCTATAG       chrY  58996471-58996488(+)
# 37926587  TAGGCTCTGCCTATAGG       chrY  58996472-58996489(+)
# 37926590  GTCTGGGCTCTGCCTAC       chrY  58996742-58996759(+)
# 37926591  TCTGGGCTCTGCCTACT       chrY  58996743-58996760(+)
# 37926592  GTCTAGGATCTGCCTAC       chrY  58996877-58996894(+)
# 37926593  CAAGTGGTATATCACCT       chrY  58996930-58996947(-)
# 37926594  ACAAGTGGTATATCACC       chrY  58996931-58996948(-)
# 37926595  TGATATACCACTTGTCA       chrY  58996933-58996950(+)
# 37926600  TAGGCTTTGCCTACAGT       chrY  58997356-58997373(+)
# 37926601  TCTCTGCACTGATCACC       chrY  58997453-58997470(+)
# 37926602  TTGTCAAAATTCCCTGT       chrY  58997502-58997519(-)
# 37926603  TGCCCCCTGTAGGCAGA       chrY  58997562-58997579(-)
# 37926604  ATGCCCCCTGTAGGCAG       chrY  58997563-58997580(-)
# 37926606  CACTGATCACCCAGGTG       chrY  58997595-58997612(+)
# 37926607  TGATGCAACTCTTGTCT       chrY  58997748-58997765(+)
# 37926608  GTCTAGGATCTGCCTAC       chrY  58997761-58997778(+)
# 37926905  ACACTAAACACTTCCCC       chrY  59013072-59013089(+)
# 37926907  CTAAAGACAGCTGGGAC       chrY  59013278-59013295(-)
# 37926908  ACCAACTAAAGACAGCT       chrY  59013283-59013300(-)
# 37926909  GACCAACTAAAGACAGC       chrY  59013284-59013301(-)
# 37926910  TCCCAGCTGTCTTTAGT       chrY  59013279-59013296(+)
# 37926911  AGTTGGAGAAATTACAG       chrY  59013372-59013389(-)
# 37926912  TTTCTCCTCTGTAAACC       chrY  59013471-59013488(+)
# 37927077  TTTCTCCTCTGTAAACC       chrY  59024983-59025000(-)
# 37927078  AGTTGGAGAAATTACAG       chrY  59025082-59025099(+)
# 37927079  TCCCAGCTGTCTTTAGT       chrY  59025175-59025192(-)
# 37927080  GACCAACTAAAGACAGC       chrY  59025170-59025187(+)
# 37927081  ACCAACTAAAGACAGCT       chrY  59025171-59025188(+)
# 37927082  CTAAAGACAGCTGGGAC       chrY  59025176-59025193(+)
# 37927084  ACACTAAACACTTCCCC       chrY  59025382-59025399(-)
#
# [6380937 rows x 3 columns]

# %% [markdown]
# Saving the sequences that are present only on one chromosome. This will be used for further analysis in the next notebook.

# %%
file_path = "/home/user/Desktop/nt_17/dup_uni/"
filename = file_path+"dup_with_one_chrom.fa"
dups_reduced.to_csv(filename,header=None,index=None,sep='\t')

# %%
#Rechecking again to make sure that only sequences which are present on only one chromosome are retained.
data3 = dups_reduced.groupby(['Sequence'])['Chromosome'].unique().value_counts()

# %%
data3
# Out:
# [chr1]     223529
# [chr2]     205628
# [chr7]     205385
# [chrX]     163933
# [chr16]    149186
# [chr9]     139911
# [chrY]     134147
# [chr17]    132270
# [chr10]    132063
# [chr15]    128045
# [chr5]      91732
# [chr19]     91191
# [chr11]     79899
# [chr8]      75362
# [chr6]      74067
# [chr22]     66408
# [chr12]     59395
# [chr3]      58371
# [chr4]      56389
# [chr14]     35102
# [chr13]     33237
# [chr20]     28389
# [chr18]     18848
# [chr21]     10701
# Name: Chromosome, dtype: int64

# %% [markdown]
# As can be seen above we only have sequences that present only one chromosome. We don't have any sequences that are [chr1][chr3]...etc. Also we now have a count of how many sequences are present on each chromosome.
